# %%
import pandas as pd

# Load the data
input_file = "C:\\Users\\ADWIN ADI\\Downloads\\MainData.csv"
output_file = "C:\Users\\ADWIN ADI\\Downloads\\MainData_modified.csv"

df = pd.read_csv(input_file)

# Keep only the first 7 columns
df_filtered = df.iloc[:, :7]

# Save the new file
df_filtered.to_csv(output_file, index=False)

print(f'Filtered CSV saved as {output_file}')

# %%
import pandas as pd
import numpy as np
from scipy.signal import detrend

# Load the data
input_file ="C:\\Users\\ADWIN ADI\\Downloads\\MainData_NaN_Removed.csv"
output_file = "C:\\Users\\ADWIN ADI\\Downloads\\Maindata_BW_removed.csv"

df = pd.read_csv(input_file)

# Keep only the first 7 columns
df_filtered = df.iloc[:, :6]

# Remove baseline wandering using detrend
df_filtered = df_filtered.apply(detrend, axis=0)

# Save the new file
df_filtered.to_csv(output_file, index=False)

print(f'Baseline wandering removed CSV saved as {output_file}')
# Out:
# Baseline wandering removed CSV saved as C:\Users\ADWIN ADI\Downloads\Maindata_BW_removed.csv

# %%
import pandas as pd



# Load the data
input_file = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\MainData.csv"
output_file = "C:\\Users\\ADWIN ADI\\Downloads\\MainData_nan_removed.csv"
df = pd.read_csv(input_file)
df = df.iloc[:, :7]  # Keep first 7 columns
df = df.dropna()     # Remove rows with missing values
df.to_csv(output_file, index=False)
print(f'Filtered CSV saved as {output_file}')
# Out:
# Filtered CSV saved as C:\Users\ADWIN ADI\Downloads\MainData_nan_removed.csv

# %%
#RNN MODEL
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc,precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\Maindata_BW_removed.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build SimpleRNN model
model = Sequential([
    SimpleRNN(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    SimpleRNN(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0     -0.241342         -2.692925         16.707508     -0.750359
# 1     -0.251330         -2.692917         16.707444     -0.760348
# 2     -0.261318         -2.696909         16.887379     -0.770338
# 3     -0.261306         -2.700401         17.017314     -0.770327
# 4     -0.261293         -2.700393         17.077249     -0.770317
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0         -2.021819         14.215375     N
# 1         -2.011612         14.215296     N
# 2         -1.996005         14.305217     N
# 3         -2.006498         14.325137     N
# 4         -2.006492         14.325058     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 5s 117ms/step - loss: 0.9374 - accuracy: 0.5751 - val_loss: 0.8417 - val_accuracy: 0.6599
# Epoch 2/50
# 19/19 [==============================] - 2s 85ms/step - loss: 0.8891 - accuracy: 0.6075 - val_loss: 0.7833 - val_accuracy: 0.6803
# Epoch 3/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.8484 - accuracy: 0.6177 - val_loss: 0.7729 - val_accuracy: 0.6939
# Epoch 4/50
# 19/19 [==============================] - 2s 85ms/step - loss: 0.8542 - accuracy: 0.6109 - val_loss: 0.7723 - val_accuracy: 0.6803
# Epoch 5/50
# 19/19 [==============================] - 2s 86ms/step - loss: 0.8080 - accuracy: 0.6348 - val_loss: 0.7492 - val_accuracy: 0.6735
# Epoch 6/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.7927 - accuracy: 0.6451 - val_loss: 0.7299 - val_accuracy: 0.6871
# Epoch 7/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.7971 - accuracy: 0.6553 - val_loss: 0.7221 - val_accuracy: 0.7007
# Epoch 8/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.7487 - accuracy: 0.6775 - val_loss: 0.7170 - val_accuracy: 0.7211
# Epoch 9/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.7621 - accuracy: 0.6672 - val_loss: 0.7052 - val_accuracy: 0.7075
# Epoch 10/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.7254 - accuracy: 0.6741 - val_loss: 0.7119 - val_accuracy: 0.6803
# Epoch 11/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.7112 - accuracy: 0.6945 - val_loss: 0.6322 - val_accuracy: 0.7279
# Epoch 12/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.7159 - accuracy: 0.6826 - val_loss: 0.7107 - val_accuracy: 0.6735
# Epoch 13/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.6775 - accuracy: 0.7099 - val_loss: 0.6854 - val_accuracy: 0.7687
# Epoch 14/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.6760 - accuracy: 0.7133 - val_loss: 0.5896 - val_accuracy: 0.7755
# Epoch 15/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.6205 - accuracy: 0.7474 - val_loss: 0.5615 - val_accuracy: 0.7755
# Epoch 16/50
# 19/19 [==============================] - 2s 81ms/step - loss: 0.6349 - accuracy: 0.7440 - val_loss: 0.6037 - val_accuracy: 0.8027
# Epoch 17/50
# 19/19 [==============================] - 2s 81ms/step - loss: 0.6168 - accuracy: 0.7338 - val_loss: 0.6222 - val_accuracy: 0.7415
# Epoch 18/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.6357 - accuracy: 0.7133 - val_loss: 0.5444 - val_accuracy: 0.7891
# Epoch 19/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.6300 - accuracy: 0.7372 - val_loss: 0.7144 - val_accuracy: 0.6939
# Epoch 20/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.6750 - accuracy: 0.6997 - val_loss: 0.6077 - val_accuracy: 0.7755
# Epoch 21/50
# 19/19 [==============================] - 2s 86ms/step - loss: 0.5992 - accuracy: 0.7509 - val_loss: 0.5900 - val_accuracy: 0.7823
# Epoch 22/50
# 19/19 [==============================] - 2s 87ms/step - loss: 0.5954 - accuracy: 0.7628 - val_loss: 0.5298 - val_accuracy: 0.8163
# Epoch 23/50
# 19/19 [==============================] - 2s 85ms/step - loss: 0.5624 - accuracy: 0.7713 - val_loss: 0.5341 - val_accuracy: 0.8367
# Epoch 24/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.5851 - accuracy: 0.7679 - val_loss: 0.5638 - val_accuracy: 0.7755
# Epoch 25/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.5426 - accuracy: 0.7765 - val_loss: 0.5081 - val_accuracy: 0.8163
# Epoch 26/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.6234 - accuracy: 0.7304 - val_loss: 0.5917 - val_accuracy: 0.7143
# Epoch 27/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.6209 - accuracy: 0.7116 - val_loss: 0.5547 - val_accuracy: 0.7415
# Epoch 28/50
# 19/19 [==============================] - 2s 83ms/step - loss: 0.6296 - accuracy: 0.7150 - val_loss: 0.5497 - val_accuracy: 0.7823
# Epoch 29/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.5772 - accuracy: 0.7594 - val_loss: 0.5080 - val_accuracy: 0.8367
# Epoch 30/50
# 19/19 [==============================] - 2s 80ms/step - loss: 0.5808 - accuracy: 0.7509 - val_loss: 0.5031 - val_accuracy: 0.8163
# Epoch 31/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.5022 - accuracy: 0.8038 - val_loss: 0.5668 - val_accuracy: 0.7755
# Epoch 32/50
# 19/19 [==============================] - 2s 85ms/step - loss: 0.5356 - accuracy: 0.7696 - val_loss: 0.5190 - val_accuracy: 0.8231
# Epoch 33/50
# 19/19 [==============================] - 2s 87ms/step - loss: 0.4852 - accuracy: 0.8106 - val_loss: 0.4503 - val_accuracy: 0.8095
# Epoch 34/50
# 19/19 [==============================] - 2s 82ms/step - loss: 0.4596 - accuracy: 0.8191 - val_loss: 0.5714 - val_accuracy: 0.7891
# Epoch 35/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.4795 - accuracy: 0.7969 - val_loss: 0.4900 - val_accuracy: 0.8027
# Epoch 36/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.4553 - accuracy: 0.8225 - val_loss: 0.6012 - val_accuracy: 0.7483
# Epoch 37/50
# 19/19 [==============================] - 1s 64ms/step - loss: 0.4683 - accuracy: 0.7969 - val_loss: 0.4634 - val_accuracy: 0.7959
# Epoch 38/50
# 19/19 [==============================] - 2s 85ms/step - loss: 0.4131 - accuracy: 0.8328 - val_loss: 0.4355 - val_accuracy: 0.8095
# Epoch 39/50
# 19/19 [==============================] - 2s 85ms/step - loss: 0.4173 - accuracy: 0.8362 - val_loss: 0.4708 - val_accuracy: 0.8231
# Epoch 40/50
# 19/19 [==============================] - 2s 88ms/step - loss: 0.8040 - accuracy: 0.6331 - val_loss: 0.7173 - val_accuracy: 0.7007
# Epoch 41/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.8644 - accuracy: 0.6570 - val_loss: 0.6885 - val_accuracy: 0.7279
# Epoch 42/50
# 19/19 [==============================] - 2s 90ms/step - loss: 0.6655 - accuracy: 0.7372 - val_loss: 0.5662 - val_accuracy: 0.7687
# Epoch 43/50
# 19/19 [==============================] - 2s 86ms/step - loss: 0.5952 - accuracy: 0.7611 - val_loss: 0.6042 - val_accuracy: 0.7823
# Epoch 44/50
# 19/19 [==============================] - 2s 87ms/step - loss: 0.5859 - accuracy: 0.7747 - val_loss: 0.5613 - val_accuracy: 0.7959
# Epoch 45/50
# 19/19 [==============================] - 2s 89ms/step - loss: 0.5279 - accuracy: 0.7816 - val_loss: 0.4743 - val_accuracy: 0.8163
# Epoch 46/50
# 19/19 [==============================] - 2s 91ms/step - loss: 0.5320 - accuracy: 0.7747 - val_loss: 0.5149 - val_accuracy: 0.7959
# Epoch 47/50
# 19/19 [==============================] - 2s 86ms/step - loss: 0.5073 - accuracy: 0.7765 - val_loss: 0.5266 - val_accuracy: 0.7823
# Epoch 48/50
# 19/19 [==============================] - 2s 87ms/step - loss: 0.5001 - accuracy: 0.7850 - val_loss: 0.5370 - val_accuracy: 0.8231
# Epoch 49/50
# 19/19 [==============================] - 2s 86ms/step - loss: 0.4619 - accuracy: 0.8106 - val_loss: 0.5398 - val_accuracy: 0.7755
# Epoch 50/50
# 19/19 [==============================] - 2s 88ms/step - loss: 0.4758 - accuracy: 0.7901 - val_loss: 0.5196 - val_accuracy: 0.7959
# Performance Metrics:
#      Metric  Endurance Breathing  Normal Breathing  Recovery Breathing
# 0      Loss             0.519579          0.519579            0.519579
# 1  Accuracy             0.795918          0.795918            0.795918
# 2  F1 Score             0.538462          0.870000            0.676471
# Model training completed and saved.

# %%
#LSTM MODEL
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc,precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\Maindata_BW_removed.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build LSTM model
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0     -0.241342         -2.692925         16.707508     -0.750359
# 1     -0.251330         -2.692917         16.707444     -0.760348
# 2     -0.261318         -2.696909         16.887379     -0.770338
# 3     -0.261306         -2.700401         17.017314     -0.770327
# 4     -0.261293         -2.700393         17.077249     -0.770317
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0         -2.021819         14.215375     N
# 1         -2.011612         14.215296     N
# 2         -1.996005         14.305217     N
# 3         -2.006498         14.325137     N
# 4         -2.006492         14.325058     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 12s 270ms/step - loss: 0.9977 - accuracy: 0.5461 - val_loss: 0.8922 - val_accuracy: 0.6599
# Epoch 2/50
# 19/19 [==============================] - 3s 185ms/step - loss: 0.8721 - accuracy: 0.6297 - val_loss: 0.7798 - val_accuracy: 0.6599
# Epoch 3/50
# 19/19 [==============================] - 3s 177ms/step - loss: 0.8124 - accuracy: 0.6314 - val_loss: 0.7591 - val_accuracy: 0.6463
# Epoch 4/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.7609 - accuracy: 0.6604 - val_loss: 0.6896 - val_accuracy: 0.6735
# Epoch 5/50
# 19/19 [==============================] - 3s 179ms/step - loss: 0.7301 - accuracy: 0.6775 - val_loss: 0.6955 - val_accuracy: 0.6667
# Epoch 6/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.7178 - accuracy: 0.6672 - val_loss: 0.6416 - val_accuracy: 0.7143
# Epoch 7/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.6200 - accuracy: 0.7133 - val_loss: 0.6102 - val_accuracy: 0.7347
# Epoch 8/50
# 19/19 [==============================] - 3s 182ms/step - loss: 0.6410 - accuracy: 0.7235 - val_loss: 0.6218 - val_accuracy: 0.7279
# Epoch 9/50
# 19/19 [==============================] - 3s 178ms/step - loss: 0.6103 - accuracy: 0.7440 - val_loss: 0.5824 - val_accuracy: 0.7483
# Epoch 10/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.5915 - accuracy: 0.7645 - val_loss: 0.6248 - val_accuracy: 0.6871
# Epoch 11/50
# 19/19 [==============================] - 3s 182ms/step - loss: 0.5426 - accuracy: 0.7679 - val_loss: 0.5561 - val_accuracy: 0.7619
# Epoch 12/50
# 19/19 [==============================] - 3s 183ms/step - loss: 0.5169 - accuracy: 0.7850 - val_loss: 0.6012 - val_accuracy: 0.7347
# Epoch 13/50
# 19/19 [==============================] - 3s 183ms/step - loss: 0.5907 - accuracy: 0.7406 - val_loss: 0.7578 - val_accuracy: 0.6803
# Epoch 14/50
# 19/19 [==============================] - 3s 162ms/step - loss: 0.6520 - accuracy: 0.6877 - val_loss: 0.6144 - val_accuracy: 0.7007
# Epoch 15/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.5793 - accuracy: 0.7201 - val_loss: 0.5796 - val_accuracy: 0.7483
# Epoch 16/50
# 19/19 [==============================] - 4s 193ms/step - loss: 0.5642 - accuracy: 0.7628 - val_loss: 0.5480 - val_accuracy: 0.7687
# Epoch 17/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.5465 - accuracy: 0.7816 - val_loss: 0.5523 - val_accuracy: 0.7687
# Epoch 18/50
# 19/19 [==============================] - 4s 195ms/step - loss: 0.5088 - accuracy: 0.7799 - val_loss: 0.5236 - val_accuracy: 0.7823
# Epoch 19/50
# 19/19 [==============================] - 4s 187ms/step - loss: 0.4688 - accuracy: 0.8157 - val_loss: 0.4706 - val_accuracy: 0.7823
# Epoch 20/50
# 19/19 [==============================] - 4s 188ms/step - loss: 0.5256 - accuracy: 0.7986 - val_loss: 0.5687 - val_accuracy: 0.7755
# Epoch 21/50
# 19/19 [==============================] - 3s 185ms/step - loss: 0.4766 - accuracy: 0.8259 - val_loss: 0.5256 - val_accuracy: 0.7823
# Epoch 22/50
# 19/19 [==============================] - 4s 185ms/step - loss: 0.4858 - accuracy: 0.8089 - val_loss: 0.4643 - val_accuracy: 0.7891
# Epoch 23/50
# 19/19 [==============================] - 3s 185ms/step - loss: 0.4292 - accuracy: 0.8379 - val_loss: 0.4665 - val_accuracy: 0.8163
# Epoch 24/50
# 19/19 [==============================] - 4s 185ms/step - loss: 0.4580 - accuracy: 0.8362 - val_loss: 0.4685 - val_accuracy: 0.8367
# Epoch 25/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.3959 - accuracy: 0.8464 - val_loss: 0.4385 - val_accuracy: 0.8435
# Epoch 26/50
# 19/19 [==============================] - 3s 178ms/step - loss: 0.3846 - accuracy: 0.8601 - val_loss: 0.5165 - val_accuracy: 0.7687
# Epoch 27/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.4907 - accuracy: 0.8140 - val_loss: 0.4817 - val_accuracy: 0.7959
# Epoch 28/50
# 19/19 [==============================] - 4s 185ms/step - loss: 0.3891 - accuracy: 0.8532 - val_loss: 0.4956 - val_accuracy: 0.8163
# Epoch 29/50
# 19/19 [==============================] - 3s 185ms/step - loss: 0.4220 - accuracy: 0.8294 - val_loss: 0.4627 - val_accuracy: 0.8027
# Epoch 30/50
# 19/19 [==============================] - 3s 182ms/step - loss: 0.3876 - accuracy: 0.8413 - val_loss: 0.4678 - val_accuracy: 0.7755
# Epoch 31/50
# 19/19 [==============================] - 3s 183ms/step - loss: 0.3472 - accuracy: 0.8635 - val_loss: 0.5319 - val_accuracy: 0.7823
# Epoch 32/50
# 19/19 [==============================] - 3s 183ms/step - loss: 0.4469 - accuracy: 0.8584 - val_loss: 0.7215 - val_accuracy: 0.7823
# Epoch 33/50
# 19/19 [==============================] - 3s 178ms/step - loss: 0.5705 - accuracy: 0.8225 - val_loss: 0.6370 - val_accuracy: 0.7755
# Epoch 34/50
# 19/19 [==============================] - 3s 177ms/step - loss: 0.5186 - accuracy: 0.8055 - val_loss: 0.4956 - val_accuracy: 0.8027
# Epoch 35/50
# 19/19 [==============================] - 3s 174ms/step - loss: 0.5088 - accuracy: 0.8089 - val_loss: 0.5588 - val_accuracy: 0.7687
# Epoch 36/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.4401 - accuracy: 0.8498 - val_loss: 0.5097 - val_accuracy: 0.7959
# Epoch 37/50
# 19/19 [==============================] - 3s 182ms/step - loss: 0.5302 - accuracy: 0.7986 - val_loss: 0.6719 - val_accuracy: 0.7347
# Epoch 38/50
# 19/19 [==============================] - 3s 185ms/step - loss: 0.5671 - accuracy: 0.7679 - val_loss: 0.5455 - val_accuracy: 0.7755
# Epoch 39/50
# 19/19 [==============================] - 4s 192ms/step - loss: 0.4822 - accuracy: 0.8003 - val_loss: 0.6220 - val_accuracy: 0.6939
# Epoch 40/50
# 19/19 [==============================] - 4s 196ms/step - loss: 0.4311 - accuracy: 0.8430 - val_loss: 0.4624 - val_accuracy: 0.7959
# Epoch 41/50
# 19/19 [==============================] - 4s 198ms/step - loss: 0.3431 - accuracy: 0.8754 - val_loss: 0.3608 - val_accuracy: 0.8435
# Epoch 42/50
# 19/19 [==============================] - 4s 194ms/step - loss: 0.3300 - accuracy: 0.8976 - val_loss: 0.4439 - val_accuracy: 0.8095
# Epoch 43/50
# 19/19 [==============================] - 4s 192ms/step - loss: 0.3980 - accuracy: 0.8635 - val_loss: 0.4616 - val_accuracy: 0.8367
# Epoch 44/50
# 19/19 [==============================] - 4s 190ms/step - loss: 0.3681 - accuracy: 0.8805 - val_loss: 0.5670 - val_accuracy: 0.7823
# Epoch 45/50
# 19/19 [==============================] - 4s 192ms/step - loss: 0.4393 - accuracy: 0.8311 - val_loss: 0.3991 - val_accuracy: 0.8707
# Epoch 46/50
# 19/19 [==============================] - 4s 193ms/step - loss: 0.3808 - accuracy: 0.8601 - val_loss: 0.7297 - val_accuracy: 0.7211
# Epoch 47/50
# 19/19 [==============================] - 4s 191ms/step - loss: 0.6358 - accuracy: 0.7662 - val_loss: 0.5680 - val_accuracy: 0.7823
# Epoch 48/50
# 19/19 [==============================] - 4s 187ms/step - loss: 0.5012 - accuracy: 0.7952 - val_loss: 0.4608 - val_accuracy: 0.8299
# Epoch 49/50
# 19/19 [==============================] - 4s 190ms/step - loss: 0.3696 - accuracy: 0.8686 - val_loss: 0.3504 - val_accuracy: 0.8844
# Epoch 50/50
# 19/19 [==============================] - 4s 187ms/step - loss: 0.3897 - accuracy: 0.8771 - val_loss: 0.4256 - val_accuracy: 0.8639
# Performance Metrics:
#      Metric  Endurance Breathing  Normal Breathing  Recovery Breathing
# 0      Loss             0.425619          0.425619            0.425619
# 1  Accuracy             0.863946          0.863946            0.863946
# 2  F1 Score             0.833333          0.909091            0.693878
# Model training completed and saved.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\Maindata_BW_removed.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build GRU model
model = Sequential([
    GRU(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    GRU(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0     -0.241342         -2.692925         16.707508     -0.750359
# 1     -0.251330         -2.692917         16.707444     -0.760348
# 2     -0.261318         -2.696909         16.887379     -0.770338
# 3     -0.261306         -2.700401         17.017314     -0.770327
# 4     -0.261293         -2.700393         17.077249     -0.770317
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0         -2.021819         14.215375     N
# 1         -2.011612         14.215296     N
# 2         -1.996005         14.305217     N
# 3         -2.006498         14.325137     N
# 4         -2.006492         14.325058     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 12s 256ms/step - loss: 1.0172 - accuracy: 0.5051 - val_loss: 0.9060 - val_accuracy: 0.6327
# Epoch 2/50
# 19/19 [==============================] - 3s 171ms/step - loss: 0.8786 - accuracy: 0.6212 - val_loss: 0.8055 - val_accuracy: 0.6463
# Epoch 3/50
# 19/19 [==============================] - 3s 167ms/step - loss: 0.8180 - accuracy: 0.6348 - val_loss: 0.7810 - val_accuracy: 0.6531
# Epoch 4/50
# 19/19 [==============================] - 3s 178ms/step - loss: 0.7885 - accuracy: 0.6502 - val_loss: 0.7570 - val_accuracy: 0.6531
# Epoch 5/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.7671 - accuracy: 0.6553 - val_loss: 0.7332 - val_accuracy: 0.6871
# Epoch 6/50
# 19/19 [==============================] - 3s 184ms/step - loss: 0.7429 - accuracy: 0.6604 - val_loss: 0.7188 - val_accuracy: 0.6939
# Epoch 7/50
# 19/19 [==============================] - 3s 180ms/step - loss: 0.7338 - accuracy: 0.6775 - val_loss: 0.7118 - val_accuracy: 0.6599
# Epoch 8/50
# 19/19 [==============================] - 3s 179ms/step - loss: 0.7276 - accuracy: 0.6758 - val_loss: 0.6824 - val_accuracy: 0.7007
# Epoch 9/50
# 19/19 [==============================] - 3s 180ms/step - loss: 0.7056 - accuracy: 0.6928 - val_loss: 0.6860 - val_accuracy: 0.6599
# Epoch 10/50
# 19/19 [==============================] - 3s 179ms/step - loss: 0.6895 - accuracy: 0.6945 - val_loss: 0.6826 - val_accuracy: 0.6939
# Epoch 11/50
# 19/19 [==============================] - 3s 173ms/step - loss: 0.6639 - accuracy: 0.7082 - val_loss: 0.6718 - val_accuracy: 0.6871
# Epoch 12/50
# 19/19 [==============================] - 3s 180ms/step - loss: 0.6511 - accuracy: 0.7270 - val_loss: 0.6296 - val_accuracy: 0.7007
# Epoch 13/50
# 19/19 [==============================] - 3s 184ms/step - loss: 0.6425 - accuracy: 0.7338 - val_loss: 0.6535 - val_accuracy: 0.7007
# Epoch 14/50
# 19/19 [==============================] - 4s 187ms/step - loss: 0.6326 - accuracy: 0.7116 - val_loss: 0.6338 - val_accuracy: 0.7143
# Epoch 15/50
# 19/19 [==============================] - 4s 185ms/step - loss: 0.6177 - accuracy: 0.7440 - val_loss: 0.6158 - val_accuracy: 0.7075
# Epoch 16/50
# 19/19 [==============================] - 4s 193ms/step - loss: 0.5997 - accuracy: 0.7491 - val_loss: 0.6244 - val_accuracy: 0.7075
# Epoch 17/50
# 19/19 [==============================] - 4s 192ms/step - loss: 0.5867 - accuracy: 0.7338 - val_loss: 0.5953 - val_accuracy: 0.7211
# Epoch 18/50
# 19/19 [==============================] - 4s 187ms/step - loss: 0.5608 - accuracy: 0.7594 - val_loss: 0.5948 - val_accuracy: 0.7211
# Epoch 19/50
# 19/19 [==============================] - 3s 183ms/step - loss: 0.5649 - accuracy: 0.7679 - val_loss: 0.5609 - val_accuracy: 0.7415
# Epoch 20/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.5456 - accuracy: 0.7577 - val_loss: 0.5530 - val_accuracy: 0.7551
# Epoch 21/50
# 19/19 [==============================] - 4s 187ms/step - loss: 0.5448 - accuracy: 0.7679 - val_loss: 0.5269 - val_accuracy: 0.7551
# Epoch 22/50
# 19/19 [==============================] - 4s 188ms/step - loss: 0.5017 - accuracy: 0.7935 - val_loss: 0.5416 - val_accuracy: 0.7619
# Epoch 23/50
# 19/19 [==============================] - 4s 188ms/step - loss: 0.4997 - accuracy: 0.7986 - val_loss: 0.5325 - val_accuracy: 0.7755
# Epoch 24/50
# 19/19 [==============================] - 3s 184ms/step - loss: 0.5091 - accuracy: 0.7901 - val_loss: 0.5365 - val_accuracy: 0.7551
# Epoch 25/50
# 19/19 [==============================] - 3s 182ms/step - loss: 0.4703 - accuracy: 0.8055 - val_loss: 0.4710 - val_accuracy: 0.7891
# Epoch 26/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.5508 - accuracy: 0.7526 - val_loss: 0.5911 - val_accuracy: 0.7211
# Epoch 27/50
# 19/19 [==============================] - 3s 184ms/step - loss: 0.4794 - accuracy: 0.8072 - val_loss: 0.5011 - val_accuracy: 0.7687
# Epoch 28/50
# 19/19 [==============================] - 3s 184ms/step - loss: 0.4504 - accuracy: 0.8191 - val_loss: 0.4953 - val_accuracy: 0.7823
# Epoch 29/50
# 19/19 [==============================] - 4s 192ms/step - loss: 0.4164 - accuracy: 0.8447 - val_loss: 0.5035 - val_accuracy: 0.7959
# Epoch 30/50
# 19/19 [==============================] - 4s 210ms/step - loss: 0.4210 - accuracy: 0.8208 - val_loss: 0.4564 - val_accuracy: 0.7959
# Epoch 31/50
# 19/19 [==============================] - 4s 190ms/step - loss: 0.4139 - accuracy: 0.8396 - val_loss: 0.4364 - val_accuracy: 0.8095
# Epoch 32/50
# 19/19 [==============================] - 4s 190ms/step - loss: 0.3905 - accuracy: 0.8447 - val_loss: 0.4351 - val_accuracy: 0.8027
# Epoch 33/50
# 19/19 [==============================] - 4s 189ms/step - loss: 0.3805 - accuracy: 0.8447 - val_loss: 0.4439 - val_accuracy: 0.8095
# Epoch 34/50
# 19/19 [==============================] - 3s 185ms/step - loss: 0.4155 - accuracy: 0.8191 - val_loss: 0.4793 - val_accuracy: 0.8027
# Epoch 35/50
# 19/19 [==============================] - 3s 185ms/step - loss: 0.4170 - accuracy: 0.8362 - val_loss: 0.4349 - val_accuracy: 0.8231
# Epoch 36/50
# 19/19 [==============================] - 3s 175ms/step - loss: 0.3462 - accuracy: 0.8379 - val_loss: 0.4200 - val_accuracy: 0.8299
# Epoch 37/50
# 19/19 [==============================] - 3s 175ms/step - loss: 0.3264 - accuracy: 0.8823 - val_loss: 0.4110 - val_accuracy: 0.8435
# Epoch 38/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.3214 - accuracy: 0.8737 - val_loss: 0.3959 - val_accuracy: 0.8163
# Epoch 39/50
# 19/19 [==============================] - 3s 184ms/step - loss: 0.3082 - accuracy: 0.8788 - val_loss: 0.4410 - val_accuracy: 0.8435
# Epoch 40/50
# 19/19 [==============================] - 3s 184ms/step - loss: 0.3271 - accuracy: 0.8635 - val_loss: 0.3735 - val_accuracy: 0.8367
# Epoch 41/50
# 19/19 [==============================] - 3s 180ms/step - loss: 0.4066 - accuracy: 0.8396 - val_loss: 0.3850 - val_accuracy: 0.8367
# Epoch 42/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.2953 - accuracy: 0.8805 - val_loss: 0.4329 - val_accuracy: 0.8163
# Epoch 43/50
# 19/19 [==============================] - 4s 187ms/step - loss: 0.3176 - accuracy: 0.8840 - val_loss: 0.4339 - val_accuracy: 0.8299
# Epoch 44/50
# 19/19 [==============================] - 4s 186ms/step - loss: 0.2645 - accuracy: 0.8993 - val_loss: 0.3801 - val_accuracy: 0.8571
# Epoch 45/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.2715 - accuracy: 0.8942 - val_loss: 0.3589 - val_accuracy: 0.8503
# Epoch 46/50
# 19/19 [==============================] - 3s 182ms/step - loss: 0.2378 - accuracy: 0.9078 - val_loss: 0.3384 - val_accuracy: 0.8571
# Epoch 47/50
# 19/19 [==============================] - 3s 182ms/step - loss: 0.2347 - accuracy: 0.9044 - val_loss: 0.3774 - val_accuracy: 0.8707
# Epoch 48/50
# 19/19 [==============================] - 3s 183ms/step - loss: 0.2444 - accuracy: 0.9061 - val_loss: 0.3234 - val_accuracy: 0.8503
# Epoch 49/50
# 19/19 [==============================] - 3s 181ms/step - loss: 0.2011 - accuracy: 0.9352 - val_loss: 0.3197 - val_accuracy: 0.8776
# Epoch 50/50
# 19/19 [==============================] - 3s 180ms/step - loss: 0.1998 - accuracy: 0.9215 - val_loss: 0.3374 - val_accuracy: 0.8776
# Performance Metrics:
#      Metric  Endurance Breathing  Normal Breathing  Recovery Breathing
# 0      Loss             0.337416          0.337416            0.337416
# 1  Accuracy             0.877551          0.877551            0.877551
# 2  F1 Score             0.823529          0.907216            0.818182
# Model training completed and saved.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout, Input, concatenate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\Maindata_BW_removed.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Define ensemble model
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

# LSTM Branch
lstm_branch = LSTM(64, return_sequences=True)(input_layer)
lstm_branch = Dropout(0.2)(lstm_branch)
lstm_branch = LSTM(32, return_sequences=False)(lstm_branch)
lstm_branch = Dropout(0.2)(lstm_branch)

# GRU Branch
gru_branch = GRU(64, return_sequences=True)(input_layer)
gru_branch = Dropout(0.2)(gru_branch)
gru_branch = GRU(32, return_sequences=False)(gru_branch)
gru_branch = Dropout(0.2)(gru_branch)

# Concatenate branches
merged = concatenate([lstm_branch, gru_branch])
merged = Dense(16, activation='relu')(merged)
out_layer = Dense(y_train.shape[1], activation='softmax')(merged)

# Define and compile model
model = Model(inputs=input_layer, outputs=out_layer)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)

# Save trained model
model.save("/mnt/data/breathing_pattern_ensemble_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Ensemble model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0     -0.241342         -2.692925         16.707508     -0.750359
# 1     -0.251330         -2.692917         16.707444     -0.760348
# 2     -0.261318         -2.696909         16.887379     -0.770338
# 3     -0.261306         -2.700401         17.017314     -0.770327
# 4     -0.261293         -2.700393         17.077249     -0.770317
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0         -2.021819         14.215375     N
# 1         -2.011612         14.215296     N
# 2         -1.996005         14.305217     N
# 3         -2.006498         14.325137     N
# 4         -2.006492         14.325058     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 25s 477ms/step - loss: 1.0310 - accuracy: 0.5222 - val_loss: 0.9042 - val_accuracy: 0.6599
# Epoch 2/50
# 19/19 [==============================] - 4s 222ms/step - loss: 0.8845 - accuracy: 0.6212 - val_loss: 0.7892 - val_accuracy: 0.6735
# Epoch 3/50
# 19/19 [==============================] - 4s 195ms/step - loss: 0.8142 - accuracy: 0.6382 - val_loss: 0.7299 - val_accuracy: 0.6531
# Epoch 4/50
# 19/19 [==============================] - 4s 192ms/step - loss: 0.7713 - accuracy: 0.6433 - val_loss: 0.7418 - val_accuracy: 0.6054
# Epoch 5/50
# 19/19 [==============================] - 4s 193ms/step - loss: 0.7637 - accuracy: 0.6399 - val_loss: 0.6920 - val_accuracy: 0.6667
# Epoch 6/50
# 19/19 [==============================] - 4s 193ms/step - loss: 0.7066 - accuracy: 0.6826 - val_loss: 0.6476 - val_accuracy: 0.6871
# Epoch 7/50
# 19/19 [==============================] - 4s 190ms/step - loss: 0.6680 - accuracy: 0.7014 - val_loss: 0.6480 - val_accuracy: 0.6939
# Epoch 8/50
# 19/19 [==============================] - 4s 196ms/step - loss: 0.6559 - accuracy: 0.7218 - val_loss: 0.6210 - val_accuracy: 0.7279
# Epoch 9/50
# 19/19 [==============================] - 4s 198ms/step - loss: 0.5920 - accuracy: 0.7509 - val_loss: 0.6397 - val_accuracy: 0.6803
# Epoch 10/50
# 19/19 [==============================] - 4s 200ms/step - loss: 0.5868 - accuracy: 0.7457 - val_loss: 0.5885 - val_accuracy: 0.7551
# Epoch 11/50
# 19/19 [==============================] - 4s 197ms/step - loss: 0.5498 - accuracy: 0.7850 - val_loss: 0.6273 - val_accuracy: 0.7075
# Epoch 12/50
# 19/19 [==============================] - 4s 196ms/step - loss: 0.5087 - accuracy: 0.7765 - val_loss: 0.6596 - val_accuracy: 0.7143
# Epoch 13/50
# 19/19 [==============================] - 4s 197ms/step - loss: 0.5418 - accuracy: 0.7662 - val_loss: 0.5916 - val_accuracy: 0.7279
# Epoch 14/50
# 19/19 [==============================] - 4s 202ms/step - loss: 0.5566 - accuracy: 0.7474 - val_loss: 0.6788 - val_accuracy: 0.6871
# Epoch 15/50
# 19/19 [==============================] - 4s 195ms/step - loss: 0.6094 - accuracy: 0.7389 - val_loss: 0.5509 - val_accuracy: 0.6803
# Epoch 16/50
# 19/19 [==============================] - 4s 196ms/step - loss: 0.5303 - accuracy: 0.7935 - val_loss: 0.5812 - val_accuracy: 0.7211
# Epoch 17/50
# 19/19 [==============================] - 4s 197ms/step - loss: 0.5235 - accuracy: 0.7747 - val_loss: 0.5505 - val_accuracy: 0.7823
# Epoch 18/50
# 19/19 [==============================] - 4s 196ms/step - loss: 0.4551 - accuracy: 0.8089 - val_loss: 0.5103 - val_accuracy: 0.7687
# Epoch 19/50
# 19/19 [==============================] - 4s 197ms/step - loss: 0.4981 - accuracy: 0.8106 - val_loss: 0.5697 - val_accuracy: 0.7211
# Epoch 20/50
# 19/19 [==============================] - 4s 201ms/step - loss: 0.4668 - accuracy: 0.8072 - val_loss: 0.5726 - val_accuracy: 0.7755
# Epoch 21/50
# 19/19 [==============================] - 4s 200ms/step - loss: 0.4542 - accuracy: 0.8259 - val_loss: 0.4735 - val_accuracy: 0.8163
# Epoch 22/50
# 19/19 [==============================] - 4s 199ms/step - loss: 0.3909 - accuracy: 0.8396 - val_loss: 0.4794 - val_accuracy: 0.8163
# Epoch 23/50
# 19/19 [==============================] - 4s 198ms/step - loss: 0.3927 - accuracy: 0.8481 - val_loss: 0.4732 - val_accuracy: 0.7891
# Epoch 24/50
# 19/19 [==============================] - 4s 196ms/step - loss: 0.3844 - accuracy: 0.8532 - val_loss: 0.5085 - val_accuracy: 0.7959
# Epoch 25/50
# 19/19 [==============================] - 4s 197ms/step - loss: 0.3955 - accuracy: 0.8396 - val_loss: 0.5000 - val_accuracy: 0.8163
# Epoch 26/50
# 19/19 [==============================] - 4s 198ms/step - loss: 0.4109 - accuracy: 0.8635 - val_loss: 0.4850 - val_accuracy: 0.8163
# Epoch 27/50
# 19/19 [==============================] - 4s 198ms/step - loss: 0.3512 - accuracy: 0.8584 - val_loss: 0.4294 - val_accuracy: 0.8435
# Epoch 28/50
# 19/19 [==============================] - 4s 200ms/step - loss: 0.3389 - accuracy: 0.8635 - val_loss: 0.4883 - val_accuracy: 0.8095
# Epoch 29/50
# 19/19 [==============================] - 4s 199ms/step - loss: 0.3577 - accuracy: 0.8720 - val_loss: 0.4681 - val_accuracy: 0.8027
# Epoch 30/50
# 19/19 [==============================] - 4s 213ms/step - loss: 0.3280 - accuracy: 0.8737 - val_loss: 0.4210 - val_accuracy: 0.8299
# Epoch 31/50
# 19/19 [==============================] - 4s 213ms/step - loss: 0.3636 - accuracy: 0.8601 - val_loss: 0.6886 - val_accuracy: 0.7143
# Epoch 32/50
# 19/19 [==============================] - 4s 208ms/step - loss: 0.4531 - accuracy: 0.8191 - val_loss: 0.5155 - val_accuracy: 0.7891
# Epoch 33/50
# 19/19 [==============================] - 4s 200ms/step - loss: 0.3746 - accuracy: 0.8567 - val_loss: 0.5062 - val_accuracy: 0.7959
# Epoch 34/50
# 19/19 [==============================] - 4s 202ms/step - loss: 0.3626 - accuracy: 0.8669 - val_loss: 0.4541 - val_accuracy: 0.8299
# Epoch 35/50
# 19/19 [==============================] - 4s 203ms/step - loss: 0.3455 - accuracy: 0.8805 - val_loss: 0.4467 - val_accuracy: 0.8571
# Epoch 36/50
# 19/19 [==============================] - 4s 202ms/step - loss: 0.3058 - accuracy: 0.8891 - val_loss: 0.4468 - val_accuracy: 0.8503
# Epoch 37/50
# 19/19 [==============================] - 4s 199ms/step - loss: 0.2992 - accuracy: 0.8959 - val_loss: 0.4128 - val_accuracy: 0.8299
# Epoch 38/50
# 19/19 [==============================] - 4s 202ms/step - loss: 0.2550 - accuracy: 0.9044 - val_loss: 0.3779 - val_accuracy: 0.8571
# Epoch 39/50
# 19/19 [==============================] - 4s 200ms/step - loss: 0.2397 - accuracy: 0.9266 - val_loss: 0.4009 - val_accuracy: 0.8639
# Epoch 40/50
# 19/19 [==============================] - 4s 198ms/step - loss: 0.2366 - accuracy: 0.9181 - val_loss: 0.4072 - val_accuracy: 0.8435
# Epoch 41/50
# 19/19 [==============================] - 4s 201ms/step - loss: 0.2659 - accuracy: 0.9044 - val_loss: 0.3571 - val_accuracy: 0.8776
# Epoch 42/50
# 19/19 [==============================] - 4s 201ms/step - loss: 0.2230 - accuracy: 0.9198 - val_loss: 0.3821 - val_accuracy: 0.8571
# Epoch 43/50
# 19/19 [==============================] - 4s 200ms/step - loss: 0.2365 - accuracy: 0.9215 - val_loss: 0.3019 - val_accuracy: 0.8844
# Epoch 44/50
# 19/19 [==============================] - 4s 199ms/step - loss: 0.1807 - accuracy: 0.9420 - val_loss: 0.3067 - val_accuracy: 0.8844
# Epoch 45/50
# 19/19 [==============================] - 4s 200ms/step - loss: 0.1905 - accuracy: 0.9249 - val_loss: 0.3623 - val_accuracy: 0.8639
# Epoch 46/50
# 19/19 [==============================] - 4s 201ms/step - loss: 0.2405 - accuracy: 0.9113 - val_loss: 0.6245 - val_accuracy: 0.8435
# Epoch 47/50
# 19/19 [==============================] - 4s 195ms/step - loss: 0.2340 - accuracy: 0.9130 - val_loss: 0.3663 - val_accuracy: 0.8639
# Epoch 48/50
# 19/19 [==============================] - 4s 191ms/step - loss: 0.2668 - accuracy: 0.8959 - val_loss: 0.3550 - val_accuracy: 0.8912
# Epoch 49/50
# 19/19 [==============================] - 4s 192ms/step - loss: 0.1942 - accuracy: 0.9334 - val_loss: 0.3552 - val_accuracy: 0.8776
# Epoch 50/50
# 19/19 [==============================] - 4s 190ms/step - loss: 0.1513 - accuracy: 0.9488 - val_loss: 0.3876 - val_accuracy: 0.8707
# Performance Metrics:
#      Metric  Endurance Breathing  Normal Breathing  Recovery Breathing
# 0      Loss             0.387566          0.387566            0.387566
# 1  Accuracy             0.870748          0.870748            0.870748
# 2  F1 Score             0.717949          0.933333            0.766667
# Ensemble model training completed and saved.
