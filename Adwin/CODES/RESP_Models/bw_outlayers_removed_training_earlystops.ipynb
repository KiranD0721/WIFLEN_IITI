# %%
#RNN MODEL
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib
from tensorflow.keras.callbacks import EarlyStopping

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\MainData_Cleaned_QIR.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build SimpleRNN model
model = Sequential([
    SimpleRNN(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    SimpleRNN(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32,callbacks=[early_stopping])

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0          0.06            0.0263              0.01          0.05
# 1          0.05            0.0261              0.01          0.04
# 2          0.04            0.0221              0.19          0.03
# 3          0.04            0.0119              0.32          0.03
# 4          0.04            0.0117              0.38          0.03
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0            0.0338               0.0     N
# 1            0.0440               0.0     N
# 2            0.0562               0.0     N
# 3            0.0457               0.0     N
# 4            0.0344               0.0     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 3s 62ms/step - loss: 1.1147 - accuracy: 0.3464 - val_loss: 0.9207 - val_accuracy: 0.5918
# Epoch 2/50
# 19/19 [==============================] - 1s 43ms/step - loss: 0.9463 - accuracy: 0.5341 - val_loss: 0.7637 - val_accuracy: 0.7075
# Epoch 3/50
# 19/19 [==============================] - 1s 42ms/step - loss: 0.8271 - accuracy: 0.6331 - val_loss: 0.6824 - val_accuracy: 0.6871
# Epoch 4/50
# 19/19 [==============================] - 1s 44ms/step - loss: 0.7655 - accuracy: 0.6604 - val_loss: 0.6816 - val_accuracy: 0.7007
# Epoch 5/50
# 19/19 [==============================] - 1s 45ms/step - loss: 0.7502 - accuracy: 0.6468 - val_loss: 0.6927 - val_accuracy: 0.7007
# Epoch 6/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.7099 - accuracy: 0.6689 - val_loss: 0.7837 - val_accuracy: 0.6735
# Epoch 7/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.8038 - accuracy: 0.6604 - val_loss: 0.8187 - val_accuracy: 0.6871
# Epoch 8/50
# 19/19 [==============================] - 1s 44ms/step - loss: 0.8540 - accuracy: 0.6570 - val_loss: 0.7601 - val_accuracy: 0.6871
# Epoch 9/50
# 19/19 [==============================] - 1s 50ms/step - loss: 0.8025 - accuracy: 0.6826 - val_loss: 0.7059 - val_accuracy: 0.7211
# Epoch 10/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.7427 - accuracy: 0.6928 - val_loss: 0.6530 - val_accuracy: 0.7279
# Epoch 11/50
# 19/19 [==============================] - 1s 42ms/step - loss: 0.7355 - accuracy: 0.6877 - val_loss: 0.5843 - val_accuracy: 0.7483
# Epoch 12/50
# 19/19 [==============================] - 1s 42ms/step - loss: 0.7034 - accuracy: 0.7065 - val_loss: 0.7115 - val_accuracy: 0.7211
# Epoch 13/50
# 19/19 [==============================] - 1s 46ms/step - loss: 0.7420 - accuracy: 0.6826 - val_loss: 0.6115 - val_accuracy: 0.7687
# Epoch 14/50
# 19/19 [==============================] - 1s 39ms/step - loss: 0.7681 - accuracy: 0.6724 - val_loss: 0.6902 - val_accuracy: 0.6803
# Epoch 15/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.7816 - accuracy: 0.6519 - val_loss: 0.6718 - val_accuracy: 0.6871
# Epoch 16/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.7435 - accuracy: 0.6843 - val_loss: 0.6331 - val_accuracy: 0.7143
# Epoch 17/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.7059 - accuracy: 0.6843 - val_loss: 0.6357 - val_accuracy: 0.7211
# Epoch 18/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.7071 - accuracy: 0.7048 - val_loss: 0.6306 - val_accuracy: 0.6939
# Epoch 19/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.6802 - accuracy: 0.6945 - val_loss: 0.6436 - val_accuracy: 0.6803
# Epoch 20/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.6809 - accuracy: 0.7099 - val_loss: 0.6143 - val_accuracy: 0.7211
# Epoch 21/50
# 19/19 [==============================] - 1s 42ms/step - loss: 0.6819 - accuracy: 0.7116 - val_loss: 0.6126 - val_accuracy: 0.7007
# Performance Metrics:
#      Metric  Endurance Breathing  Normal Breathing  Recovery Breathing
# 0      Loss             0.584305          0.584305            0.584305
# 1  Accuracy             0.748299          0.748299            0.748299
# 2  F1 Score             0.500000          0.861386            0.500000
# Model training completed and saved.

# %%
#LSTM MODEL
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\MainData_Cleaned_QIR.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build LSTM model
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32,callbacks=[early_stopping])

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0          0.06            0.0263              0.01          0.05
# 1          0.05            0.0261              0.01          0.04
# 2          0.04            0.0221              0.19          0.03
# 3          0.04            0.0119              0.32          0.03
# 4          0.04            0.0117              0.38          0.03
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0            0.0338               0.0     N
# 1            0.0440               0.0     N
# 2            0.0562               0.0     N
# 3            0.0457               0.0     N
# 4            0.0344               0.0     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 6s 145ms/step - loss: 1.0341 - accuracy: 0.5734 - val_loss: 0.9415 - val_accuracy: 0.6599
# Epoch 2/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.8899 - accuracy: 0.6331 - val_loss: 0.7913 - val_accuracy: 0.6667
# Epoch 3/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.7361 - accuracy: 0.6997 - val_loss: 0.6464 - val_accuracy: 0.7143
# Epoch 4/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.6165 - accuracy: 0.7355 - val_loss: 0.5702 - val_accuracy: 0.8027
# Epoch 5/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.6446 - accuracy: 0.7799 - val_loss: 0.6172 - val_accuracy: 0.7483
# Epoch 6/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.5534 - accuracy: 0.7952 - val_loss: 0.4979 - val_accuracy: 0.8163
# Epoch 7/50
# 19/19 [==============================] - 2s 113ms/step - loss: 0.4879 - accuracy: 0.8328 - val_loss: 0.5063 - val_accuracy: 0.8027
# Epoch 8/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.4329 - accuracy: 0.8447 - val_loss: 0.4542 - val_accuracy: 0.8231
# Epoch 9/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.4256 - accuracy: 0.8430 - val_loss: 0.4533 - val_accuracy: 0.8367
# Epoch 10/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.4188 - accuracy: 0.8515 - val_loss: 0.4276 - val_accuracy: 0.8231
# Epoch 11/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.3883 - accuracy: 0.8549 - val_loss: 0.4039 - val_accuracy: 0.8503
# Epoch 12/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.3897 - accuracy: 0.8584 - val_loss: 0.4640 - val_accuracy: 0.8163
# Epoch 13/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.3572 - accuracy: 0.8754 - val_loss: 0.4357 - val_accuracy: 0.8299
# Epoch 14/50
# 19/19 [==============================] - 2s 112ms/step - loss: 0.3316 - accuracy: 0.8720 - val_loss: 0.3807 - val_accuracy: 0.8299
# Epoch 15/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.3157 - accuracy: 0.8669 - val_loss: 0.3885 - val_accuracy: 0.8435
# Epoch 16/50
# 19/19 [==============================] - 2s 107ms/step - loss: 0.3446 - accuracy: 0.8788 - val_loss: 0.4175 - val_accuracy: 0.8435
# Epoch 17/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.3621 - accuracy: 0.8703 - val_loss: 0.4512 - val_accuracy: 0.7823
# Epoch 18/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.5438 - accuracy: 0.7730 - val_loss: 0.6364 - val_accuracy: 0.7823
# Epoch 19/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.6530 - accuracy: 0.7355 - val_loss: 0.6946 - val_accuracy: 0.7279
# Epoch 20/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.5738 - accuracy: 0.7850 - val_loss: 0.5650 - val_accuracy: 0.8027
# Epoch 21/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.5123 - accuracy: 0.8140 - val_loss: 0.5134 - val_accuracy: 0.8299
# Epoch 22/50
# 19/19 [==============================] - 2s 98ms/step - loss: 0.4636 - accuracy: 0.8345 - val_loss: 0.4758 - val_accuracy: 0.8299
# Epoch 23/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.4281 - accuracy: 0.8515 - val_loss: 0.5057 - val_accuracy: 0.7959
# Epoch 24/50
# 19/19 [==============================] - 2s 114ms/step - loss: 0.3955 - accuracy: 0.8549 - val_loss: 0.4504 - val_accuracy: 0.8163
# Performance Metrics:
#      Metric  Endurance Breathing  Normal Breathing  Recovery Breathing
# 0      Loss             0.380673          0.380673            0.380673
# 1  Accuracy             0.829932          0.829932            0.829932
# 2  F1 Score             0.722222          0.903553            0.655738
# Model training completed and saved.

# %%
#GRU
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\MainData_Cleaned_QIR.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build GRU model
model = Sequential([
    GRU(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    GRU(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32,callbacks=[early_stopping])

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0          0.06            0.0263              0.01          0.05
# 1          0.05            0.0261              0.01          0.04
# 2          0.04            0.0221              0.19          0.03
# 3          0.04            0.0119              0.32          0.03
# 4          0.04            0.0117              0.38          0.03
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0            0.0338               0.0     N
# 1            0.0440               0.0     N
# 2            0.0562               0.0     N
# 3            0.0457               0.0     N
# 4            0.0344               0.0     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 7s 159ms/step - loss: 1.0878 - accuracy: 0.4420 - val_loss: 1.0359 - val_accuracy: 0.6599
# Epoch 2/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.9806 - accuracy: 0.6331 - val_loss: 0.8885 - val_accuracy: 0.6667
# Epoch 3/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.8520 - accuracy: 0.6331 - val_loss: 0.7429 - val_accuracy: 0.6871
# Epoch 4/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.7421 - accuracy: 0.6894 - val_loss: 0.6844 - val_accuracy: 0.7211
# Epoch 5/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.6661 - accuracy: 0.7304 - val_loss: 0.6806 - val_accuracy: 0.7143
# Epoch 6/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.6201 - accuracy: 0.7406 - val_loss: 0.6529 - val_accuracy: 0.7143
# Epoch 7/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.5918 - accuracy: 0.7560 - val_loss: 0.6197 - val_accuracy: 0.7483
# Epoch 8/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.5578 - accuracy: 0.7679 - val_loss: 0.5445 - val_accuracy: 0.7823
# Epoch 9/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.5105 - accuracy: 0.7867 - val_loss: 0.5170 - val_accuracy: 0.8231
# Epoch 10/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.4852 - accuracy: 0.8055 - val_loss: 0.4504 - val_accuracy: 0.8367
# Epoch 11/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.5395 - accuracy: 0.8055 - val_loss: 0.5234 - val_accuracy: 0.8095
# Epoch 12/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.4588 - accuracy: 0.8396 - val_loss: 0.4027 - val_accuracy: 0.8435
# Epoch 13/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.4483 - accuracy: 0.8157 - val_loss: 0.4706 - val_accuracy: 0.8027
# Epoch 14/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.4315 - accuracy: 0.8191 - val_loss: 0.4017 - val_accuracy: 0.8231
# Epoch 15/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.3955 - accuracy: 0.8259 - val_loss: 0.3771 - val_accuracy: 0.8367
# Epoch 16/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.3666 - accuracy: 0.8635 - val_loss: 0.3795 - val_accuracy: 0.8639
# Epoch 17/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.3822 - accuracy: 0.8532 - val_loss: 0.3796 - val_accuracy: 0.8571
# Epoch 18/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3344 - accuracy: 0.8669 - val_loss: 0.3769 - val_accuracy: 0.8231
# Epoch 19/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.3032 - accuracy: 0.8805 - val_loss: 0.3501 - val_accuracy: 0.8435
# Epoch 20/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.3082 - accuracy: 0.8771 - val_loss: 0.3551 - val_accuracy: 0.8639
# Epoch 21/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.2962 - accuracy: 0.8788 - val_loss: 0.3130 - val_accuracy: 0.8503
# Epoch 22/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.2926 - accuracy: 0.8976 - val_loss: 0.4223 - val_accuracy: 0.8163
# Epoch 23/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.2880 - accuracy: 0.8771 - val_loss: 0.3095 - val_accuracy: 0.8707
# Epoch 24/50
# 19/19 [==============================] - 2s 110ms/step - loss: 0.2545 - accuracy: 0.8959 - val_loss: 0.3208 - val_accuracy: 0.8503
# Epoch 25/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.2943 - accuracy: 0.8840 - val_loss: 0.3355 - val_accuracy: 0.8435
# Epoch 26/50
# 19/19 [==============================] - 2s 111ms/step - loss: 0.2779 - accuracy: 0.8874 - val_loss: 0.3517 - val_accuracy: 0.8639
# Epoch 27/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.2815 - accuracy: 0.8908 - val_loss: 0.3468 - val_accuracy: 0.8367
# Epoch 28/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.2570 - accuracy: 0.8908 - val_loss: 0.3324 - val_accuracy: 0.8639
# Epoch 29/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.3124 - accuracy: 0.8686 - val_loss: 0.3527 - val_accuracy: 0.8435
# Epoch 30/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.2463 - accuracy: 0.8942 - val_loss: 0.3651 - val_accuracy: 0.8299
# Epoch 31/50
# 19/19 [==============================] - 2s 106ms/step - loss: 0.2404 - accuracy: 0.8874 - val_loss: 0.3602 - val_accuracy: 0.8639
# Epoch 32/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.2594 - accuracy: 0.8891 - val_loss: 0.3806 - val_accuracy: 0.8503
# Epoch 33/50
# 19/19 [==============================] - 2s 98ms/step - loss: 0.2728 - accuracy: 0.8788 - val_loss: 0.3898 - val_accuracy: 0.8163
# Performance Metrics:
#      Metric  Endurance Breathing  Normal Breathing  Recovery Breathing
# 0      Loss             0.309460          0.309460            0.309460
# 1  Accuracy             0.870748          0.870748            0.870748
# 2  F1 Score             0.810811          0.931937            0.727273
# Model training completed and saved.
