# %%
#RNN MODEL
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib
from tensorflow.keras.callbacks import EarlyStopping

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\Maindata_BW_removed.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build SimpleRNN model
model = Sequential([
    SimpleRNN(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    SimpleRNN(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32,callbacks=[early_stopping])

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)

print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0     -0.241342         -2.692925         16.707508     -0.750359
# 1     -0.251330         -2.692917         16.707444     -0.760348
# 2     -0.261318         -2.696909         16.887379     -0.770338
# 3     -0.261306         -2.700401         17.017314     -0.770327
# 4     -0.261293         -2.700393         17.077249     -0.770317
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0         -2.021819         14.215375     N
# 1         -2.011612         14.215296     N
# 2         -1.996005         14.305217     N
# 3         -2.006498         14.325137     N
# 4         -2.006492         14.325058     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 3s 58ms/step - loss: 1.0585 - accuracy: 0.4812 - val_loss: 0.8566 - val_accuracy: 0.6667
# Epoch 2/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.9181 - accuracy: 0.6058 - val_loss: 0.7848 - val_accuracy: 0.6667
# Epoch 3/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.8462 - accuracy: 0.6587 - val_loss: 0.7871 - val_accuracy: 0.6803
# Epoch 4/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.8071 - accuracy: 0.6638 - val_loss: 0.7558 - val_accuracy: 0.6939
# Epoch 5/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.8107 - accuracy: 0.6536 - val_loss: 0.7676 - val_accuracy: 0.6803
# Epoch 6/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.7860 - accuracy: 0.6894 - val_loss: 0.7336 - val_accuracy: 0.7075
# Epoch 7/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.7904 - accuracy: 0.6604 - val_loss: 0.7594 - val_accuracy: 0.6939
# Epoch 8/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.7830 - accuracy: 0.6911 - val_loss: 0.7405 - val_accuracy: 0.6939
# Epoch 9/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.7391 - accuracy: 0.6997 - val_loss: 0.7060 - val_accuracy: 0.6939
# Epoch 10/50
# 19/19 [==============================] - 1s 39ms/step - loss: 0.7495 - accuracy: 0.7031 - val_loss: 0.6831 - val_accuracy: 0.7279
# Epoch 11/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.7077 - accuracy: 0.7116 - val_loss: 0.6921 - val_accuracy: 0.7007
# Epoch 12/50
# 19/19 [==============================] - 1s 39ms/step - loss: 0.7295 - accuracy: 0.7150 - val_loss: 0.7045 - val_accuracy: 0.7007
# Epoch 13/50
# 19/19 [==============================] - 1s 39ms/step - loss: 0.7173 - accuracy: 0.6997 - val_loss: 0.7044 - val_accuracy: 0.7075
# Epoch 14/50
# 19/19 [==============================] - 1s 42ms/step - loss: 0.7098 - accuracy: 0.6997 - val_loss: 0.6893 - val_accuracy: 0.7279
# Epoch 15/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6912 - accuracy: 0.7287 - val_loss: 0.6749 - val_accuracy: 0.7211
# Epoch 16/50
# 19/19 [==============================] - 1s 39ms/step - loss: 0.6907 - accuracy: 0.7184 - val_loss: 0.6395 - val_accuracy: 0.7551
# Epoch 17/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6547 - accuracy: 0.7509 - val_loss: 0.6545 - val_accuracy: 0.7279
# Epoch 18/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6911 - accuracy: 0.6980 - val_loss: 0.6490 - val_accuracy: 0.7415
# Epoch 19/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6485 - accuracy: 0.7321 - val_loss: 0.6138 - val_accuracy: 0.7551
# Epoch 20/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.6402 - accuracy: 0.7321 - val_loss: 0.6439 - val_accuracy: 0.7279
# Epoch 21/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6744 - accuracy: 0.7235 - val_loss: 0.6654 - val_accuracy: 0.7007
# Epoch 22/50
# 19/19 [==============================] - 1s 41ms/step - loss: 0.6907 - accuracy: 0.7150 - val_loss: 0.6408 - val_accuracy: 0.7347
# Epoch 23/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6532 - accuracy: 0.7235 - val_loss: 0.6171 - val_accuracy: 0.7619
# Epoch 24/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6127 - accuracy: 0.7560 - val_loss: 0.6108 - val_accuracy: 0.7415
# Epoch 25/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6113 - accuracy: 0.7423 - val_loss: 0.6819 - val_accuracy: 0.7143
# Epoch 26/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6865 - accuracy: 0.7150 - val_loss: 0.5983 - val_accuracy: 0.7551
# Epoch 27/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6085 - accuracy: 0.7389 - val_loss: 0.6442 - val_accuracy: 0.7075
# Epoch 28/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.6116 - accuracy: 0.7509 - val_loss: 0.6269 - val_accuracy: 0.7415
# Epoch 29/50
# 19/19 [==============================] - 1s 40ms/step - loss: 0.5938 - accuracy: 0.7577 - val_loss: 0.6890 - val_accuracy: 0.7075
# Epoch 30/50
# 19/19 [==============================] - 1s 39ms/step - loss: 0.6309 - accuracy: 0.7338 - val_loss: 0.6134 - val_accuracy: 0.7347
# Epoch 31/50
# 19/19 [==============================] - 1s 43ms/step - loss: 0.5715 - accuracy: 0.7765 - val_loss: 0.6052 - val_accuracy: 0.7551
# Epoch 32/50
# 19/19 [==============================] - 1s 42ms/step - loss: 0.5468 - accuracy: 0.7901 - val_loss: 0.6184 - val_accuracy: 0.7347
# Epoch 33/50
# 19/19 [==============================] - 1s 42ms/step - loss: 0.5616 - accuracy: 0.7611 - val_loss: 0.6048 - val_accuracy: 0.7551
# Epoch 34/50
# 19/19 [==============================] - 1s 43ms/step - loss: 0.5184 - accuracy: 0.7833 - val_loss: 0.6390 - val_accuracy: 0.7347
# Epoch 35/50
# 19/19 [==============================] - 1s 43ms/step - loss: 0.5421 - accuracy: 0.7935 - val_loss: 0.5992 - val_accuracy: 0.7347
# Epoch 36/50
# 19/19 [==============================] - 1s 44ms/step - loss: 0.5395 - accuracy: 0.7628 - val_loss: 0.6175 - val_accuracy: 0.7551
# Model training completed and saved.

# %%
#LSTM MODEL
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\Maindata_BW_removed.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build LSTM model
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32,callbacks=[early_stopping])

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)


print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0     -0.241342         -2.692925         16.707508     -0.750359
# 1     -0.251330         -2.692917         16.707444     -0.760348
# 2     -0.261318         -2.696909         16.887379     -0.770338
# 3     -0.261306         -2.700401         17.017314     -0.770327
# 4     -0.261293         -2.700393         17.077249     -0.770317
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0         -2.021819         14.215375     N
# 1         -2.011612         14.215296     N
# 2         -1.996005         14.305217     N
# 3         -2.006498         14.325137     N
# 4         -2.006492         14.325058     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 6s 147ms/step - loss: 0.9653 - accuracy: 0.6007 - val_loss: 0.8680 - val_accuracy: 0.6463
# Epoch 2/50
# 19/19 [==============================] - 2s 105ms/step - loss: 0.8635 - accuracy: 0.6195 - val_loss: 0.7853 - val_accuracy: 0.6327
# Epoch 3/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.7928 - accuracy: 0.6246 - val_loss: 0.7192 - val_accuracy: 0.6735
# Epoch 4/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.7573 - accuracy: 0.6451 - val_loss: 0.7076 - val_accuracy: 0.6667
# Epoch 5/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.7286 - accuracy: 0.6621 - val_loss: 0.7121 - val_accuracy: 0.6667
# Epoch 6/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.7372 - accuracy: 0.6689 - val_loss: 0.6788 - val_accuracy: 0.6463
# Epoch 7/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.6995 - accuracy: 0.6860 - val_loss: 0.6752 - val_accuracy: 0.6667
# Epoch 8/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.6770 - accuracy: 0.7065 - val_loss: 0.6442 - val_accuracy: 0.6871
# Epoch 9/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.6531 - accuracy: 0.7167 - val_loss: 0.6507 - val_accuracy: 0.6735
# Epoch 10/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.6411 - accuracy: 0.7355 - val_loss: 0.6124 - val_accuracy: 0.6871
# Epoch 11/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.5996 - accuracy: 0.7406 - val_loss: 0.6142 - val_accuracy: 0.7279
# Epoch 12/50
# 19/19 [==============================] - 2s 92ms/step - loss: 0.6624 - accuracy: 0.6894 - val_loss: 0.6251 - val_accuracy: 0.6599
# Epoch 13/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.5792 - accuracy: 0.7355 - val_loss: 0.5437 - val_accuracy: 0.7551
# Epoch 14/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.5379 - accuracy: 0.7730 - val_loss: 0.5042 - val_accuracy: 0.7687
# Epoch 15/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.4852 - accuracy: 0.7986 - val_loss: 0.4920 - val_accuracy: 0.7755
# Epoch 16/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.5663 - accuracy: 0.7730 - val_loss: 0.5201 - val_accuracy: 0.7755
# Epoch 17/50
# 19/19 [==============================] - 2s 102ms/step - loss: 0.5366 - accuracy: 0.7713 - val_loss: 0.5143 - val_accuracy: 0.7415
# Epoch 18/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.5011 - accuracy: 0.7833 - val_loss: 0.4567 - val_accuracy: 0.8027
# Epoch 19/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.4516 - accuracy: 0.8140 - val_loss: 0.4823 - val_accuracy: 0.7891
# Epoch 20/50
# 19/19 [==============================] - 2s 98ms/step - loss: 0.4500 - accuracy: 0.8089 - val_loss: 0.4444 - val_accuracy: 0.7891
# Epoch 21/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.4524 - accuracy: 0.7952 - val_loss: 0.5487 - val_accuracy: 0.7823
# Epoch 22/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.4505 - accuracy: 0.8106 - val_loss: 0.4507 - val_accuracy: 0.8095
# Epoch 23/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.4541 - accuracy: 0.8191 - val_loss: 0.5550 - val_accuracy: 0.7415
# Epoch 24/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.4269 - accuracy: 0.8106 - val_loss: 0.4180 - val_accuracy: 0.7959
# Epoch 25/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.3717 - accuracy: 0.8601 - val_loss: 0.3861 - val_accuracy: 0.8503
# Epoch 26/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.3616 - accuracy: 0.8549 - val_loss: 0.4012 - val_accuracy: 0.7891
# Epoch 27/50
# 19/19 [==============================] - 2s 98ms/step - loss: 0.3322 - accuracy: 0.8788 - val_loss: 0.3938 - val_accuracy: 0.8639
# Epoch 28/50
# 19/19 [==============================] - 2s 108ms/step - loss: 0.2959 - accuracy: 0.8908 - val_loss: 0.3247 - val_accuracy: 0.9320
# Epoch 29/50
# 19/19 [==============================] - 2s 104ms/step - loss: 0.3641 - accuracy: 0.8754 - val_loss: 0.4330 - val_accuracy: 0.8231
# Epoch 30/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.6464 - accuracy: 0.7782 - val_loss: 0.6338 - val_accuracy: 0.7755
# Epoch 31/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.7248 - accuracy: 0.7150 - val_loss: 0.5495 - val_accuracy: 0.8027
# Epoch 32/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.4164 - accuracy: 0.8618 - val_loss: 0.4641 - val_accuracy: 0.8367
# Epoch 33/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.3921 - accuracy: 0.8669 - val_loss: 0.3835 - val_accuracy: 0.8980
# Epoch 34/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.3744 - accuracy: 0.8737 - val_loss: 0.4595 - val_accuracy: 0.7959
# Epoch 35/50
# 19/19 [==============================] - 2s 99ms/step - loss: 0.3820 - accuracy: 0.8635 - val_loss: 0.5391 - val_accuracy: 0.8367
# Epoch 36/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.4297 - accuracy: 0.8430 - val_loss: 0.4281 - val_accuracy: 0.8299
# Epoch 37/50
# 19/19 [==============================] - 2s 98ms/step - loss: 0.4058 - accuracy: 0.8430 - val_loss: 0.5013 - val_accuracy: 0.7755
# Epoch 38/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.4166 - accuracy: 0.8140 - val_loss: 0.3521 - val_accuracy: 0.8707
# Model training completed and saved.

# %%
#GRU model
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_fscore_support
import joblib

# Load dataset
file_path = "C:\\Users\\ADWIN ADI\\Downloads\\breathing.csv files\\Maindata_BW_removed.csv"
df = pd.read_csv(file_path)

# Print dataset info
print("Dataset Shape:", df.shape)
print("First Few Rows:\n", df.head())

# Drop NaN values
df.dropna(inplace=True)
print("After Dropping NaN - Shape:", df.shape)

# Ensure dataset is not empty after dropping NaN values
if df.empty:
    raise ValueError("Dataset is empty after dropping NaN values. Check the CSV file!")

# Select features (all columns except the last one) and target (last column)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Encode labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
joblib.dump(label_encoder, "/mnt/data/label_encoder.pkl")

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = np.nan_to_num(X_scaled)
joblib.dump(scaler, "/mnt/data/scaler.pkl")

# Verify no NaN values exist
if np.isnan(X_scaled).any() or np.isnan(y_encoded).any():
    raise ValueError("NaN values detected in dataset after preprocessing!")

# Segment data into 10-second windows at 15 Hz (150 samples per segment)
segment_size = 150
num_segments = len(X_scaled) // segment_size
if num_segments == 0:
    raise ValueError(f"Not enough samples for segmentation! Required: {segment_size}, Found: {len(X_scaled)}")

X_segmented = np.array([X_scaled[i * segment_size:(i + 1) * segment_size] for i in range(num_segments)])

def majority_label(labels):
    return np.bincount(labels).argmax()

y_segmented = np.array([majority_label(y_encoded[i * segment_size:(i + 1) * segment_size]) for i in range(num_segments)])

# One-hot encode labels
ohe = OneHotEncoder(sparse_output=False)
y_segmented_ohe = ohe.fit_transform(y_segmented.reshape(-1, 1))

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_segmented, y_segmented_ohe, test_size=0.2, random_state=42)

# Build GRU model
model = Sequential([
    GRU(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    GRU(32, return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_train.shape[1], activation='softmax')
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)


# Train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32,callbacks=[early_stopping])

# Save trained model
model.save("/mnt/data/breathing_pattern_model.h5")

# Predict test labels
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
y_test_labels = np.argmax(y_test, axis=1)

# Confusion matrix (percentage format)
cm = confusion_matrix(y_test_labels, y_pred)
cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

plt.figure(figsize=(6, 5))
sns.heatmap(cm_percentage, annot=True, fmt='.2f', cmap='Blues', 
            xticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'], 
            yticklabels=['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Percentage)")
plt.show()

# ROC Curve
plt.figure(figsize=(6, 5))
class_labels = ['Endurance_Breathing', 'Normal_Breathing', 'Recovery_Breathing']

for i in range(y_train.shape[1]):
    fpr, tpr, _ = roc_curve(y_test[:, i], y_pred_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal reference line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Performance Table
precision, recall, f1, _ = precision_recall_fscore_support(y_test_labels, y_pred, labels=[0, 1, 2])
accuracy = np.mean(y_test_labels == y_pred)
loss = model.evaluate(X_test, y_test, verbose=0)[0]

performance_table = pd.DataFrame({
    "Metric": ["Loss", "Accuracy", "F1 Score"],
    "Endurance Breathing": [loss, accuracy, f1[0]],
    "Normal Breathing": [loss, accuracy, f1[1]],
    "Recovery Breathing": [loss, accuracy, f1[2]]
})

print("Performance Metrics:")
print(performance_table)
print("Model training completed and saved.")
# Out:
# Dataset Shape: (109971, 7)
# First Few Rows:
#     Sensor1_Temp  Sensor1_Pressure  Sensor1_Humidity  Sensor2_Temp  \
# 0     -0.241342         -2.692925         16.707508     -0.750359
# 1     -0.251330         -2.692917         16.707444     -0.760348
# 2     -0.261318         -2.696909         16.887379     -0.770338
# 3     -0.261306         -2.700401         17.017314     -0.770327
# 4     -0.261293         -2.700393         17.077249     -0.770317
#
#    Sensor2_Pressure  Sensor2_Humidity Label
# 0         -2.021819         14.215375     N
# 1         -2.011612         14.215296     N
# 2         -1.996005         14.305217     N
# 3         -2.006498         14.325137     N
# 4         -2.006492         14.325058     N
# After Dropping NaN - Shape: (109971, 7)
# Epoch 1/50
# 19/19 [==============================] - 6s 135ms/step - loss: 1.0608 - accuracy: 0.4693 - val_loss: 0.9565 - val_accuracy: 0.6463
# Epoch 2/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.9453 - accuracy: 0.6263 - val_loss: 0.8426 - val_accuracy: 0.6599
# Epoch 3/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.8643 - accuracy: 0.6246 - val_loss: 0.7921 - val_accuracy: 0.6803
# Epoch 4/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.8396 - accuracy: 0.6212 - val_loss: 0.7607 - val_accuracy: 0.6803
# Epoch 5/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.8231 - accuracy: 0.6433 - val_loss: 0.7407 - val_accuracy: 0.7007
# Epoch 6/50
# 19/19 [==============================] - 2s 95ms/step - loss: 0.7885 - accuracy: 0.6689 - val_loss: 0.7166 - val_accuracy: 0.6871
# Epoch 7/50
# 19/19 [==============================] - 2s 95ms/step - loss: 0.7633 - accuracy: 0.6741 - val_loss: 0.6966 - val_accuracy: 0.7075
# Epoch 8/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.7363 - accuracy: 0.6980 - val_loss: 0.6796 - val_accuracy: 0.7007
# Epoch 9/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.7322 - accuracy: 0.7048 - val_loss: 0.6503 - val_accuracy: 0.7347
# Epoch 10/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.6957 - accuracy: 0.7065 - val_loss: 0.6256 - val_accuracy: 0.7347
# Epoch 11/50
# 19/19 [==============================] - 2s 95ms/step - loss: 0.6721 - accuracy: 0.7253 - val_loss: 0.6199 - val_accuracy: 0.7551
# Epoch 12/50
# 19/19 [==============================] - 2s 92ms/step - loss: 0.7118 - accuracy: 0.6980 - val_loss: 0.6657 - val_accuracy: 0.7415
# Epoch 13/50
# 19/19 [==============================] - 2s 91ms/step - loss: 0.6692 - accuracy: 0.7201 - val_loss: 0.6133 - val_accuracy: 0.7415
# Epoch 14/50
# 19/19 [==============================] - 2s 92ms/step - loss: 0.6415 - accuracy: 0.7355 - val_loss: 0.6046 - val_accuracy: 0.7483
# Epoch 15/50
# 19/19 [==============================] - 2s 84ms/step - loss: 0.6358 - accuracy: 0.7406 - val_loss: 0.5865 - val_accuracy: 0.7687
# Epoch 16/50
# 19/19 [==============================] - 2s 87ms/step - loss: 0.6028 - accuracy: 0.7440 - val_loss: 0.5793 - val_accuracy: 0.7687
# Epoch 17/50
# 19/19 [==============================] - 2s 95ms/step - loss: 0.5917 - accuracy: 0.7611 - val_loss: 0.5980 - val_accuracy: 0.7483
# Epoch 18/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.7054 - accuracy: 0.7099 - val_loss: 0.6440 - val_accuracy: 0.7211
# Epoch 19/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.6659 - accuracy: 0.6928 - val_loss: 0.5998 - val_accuracy: 0.7279
# Epoch 20/50
# 19/19 [==============================] - 2s 92ms/step - loss: 0.6431 - accuracy: 0.7321 - val_loss: 0.5460 - val_accuracy: 0.7483
# Epoch 21/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.5895 - accuracy: 0.7577 - val_loss: 0.5752 - val_accuracy: 0.7279
# Epoch 22/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.5512 - accuracy: 0.7816 - val_loss: 0.5236 - val_accuracy: 0.7755
# Epoch 23/50
# 19/19 [==============================] - 2s 92ms/step - loss: 0.5445 - accuracy: 0.7713 - val_loss: 0.5101 - val_accuracy: 0.7755
# Epoch 24/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.5114 - accuracy: 0.7884 - val_loss: 0.5033 - val_accuracy: 0.7823
# Epoch 25/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.5290 - accuracy: 0.7816 - val_loss: 0.5284 - val_accuracy: 0.7619
# Epoch 26/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.5160 - accuracy: 0.7884 - val_loss: 0.5071 - val_accuracy: 0.7823
# Epoch 27/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.4850 - accuracy: 0.8072 - val_loss: 0.5142 - val_accuracy: 0.7959
# Epoch 28/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.4659 - accuracy: 0.8157 - val_loss: 0.4635 - val_accuracy: 0.8231
# Epoch 29/50
# 19/19 [==============================] - 2s 95ms/step - loss: 0.4436 - accuracy: 0.8191 - val_loss: 0.5026 - val_accuracy: 0.7755
# Epoch 30/50
# 19/19 [==============================] - 2s 95ms/step - loss: 0.4231 - accuracy: 0.8396 - val_loss: 0.4613 - val_accuracy: 0.7891
# Epoch 31/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.4122 - accuracy: 0.8345 - val_loss: 0.4435 - val_accuracy: 0.8095
# Epoch 32/50
# 19/19 [==============================] - 2s 87ms/step - loss: 0.3969 - accuracy: 0.8515 - val_loss: 0.4992 - val_accuracy: 0.7823
# Epoch 33/50
# 19/19 [==============================] - 2s 87ms/step - loss: 0.4403 - accuracy: 0.8294 - val_loss: 0.4773 - val_accuracy: 0.8163
# Epoch 34/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.4496 - accuracy: 0.8345 - val_loss: 0.4224 - val_accuracy: 0.8163
# Epoch 35/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.3814 - accuracy: 0.8567 - val_loss: 0.4720 - val_accuracy: 0.8095
# Epoch 36/50
# 19/19 [==============================] - 2s 100ms/step - loss: 0.3852 - accuracy: 0.8430 - val_loss: 0.4476 - val_accuracy: 0.7823
# Epoch 37/50
# 19/19 [==============================] - 2s 103ms/step - loss: 0.3439 - accuracy: 0.8720 - val_loss: 0.4640 - val_accuracy: 0.8231
# Epoch 38/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.3689 - accuracy: 0.8532 - val_loss: 0.3966 - val_accuracy: 0.8367
# Epoch 39/50
# 19/19 [==============================] - 2s 101ms/step - loss: 0.3162 - accuracy: 0.8618 - val_loss: 0.4390 - val_accuracy: 0.8571
# Epoch 40/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.3565 - accuracy: 0.8669 - val_loss: 0.4057 - val_accuracy: 0.8503
# Epoch 41/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3669 - accuracy: 0.8635 - val_loss: 0.3790 - val_accuracy: 0.8435
# Epoch 42/50
# 19/19 [==============================] - 2s 97ms/step - loss: 0.3053 - accuracy: 0.8874 - val_loss: 0.3625 - val_accuracy: 0.8639
# Epoch 43/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.2710 - accuracy: 0.9010 - val_loss: 0.3844 - val_accuracy: 0.8435
# Epoch 44/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.2510 - accuracy: 0.8976 - val_loss: 0.3873 - val_accuracy: 0.8639
# Epoch 45/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.2391 - accuracy: 0.9198 - val_loss: 0.3539 - val_accuracy: 0.8639
# Epoch 46/50
# 19/19 [==============================] - 2s 94ms/step - loss: 0.2697 - accuracy: 0.9061 - val_loss: 0.3880 - val_accuracy: 0.8503
# Epoch 47/50
# 19/19 [==============================] - 2s 96ms/step - loss: 0.2501 - accuracy: 0.9027 - val_loss: 0.3609 - val_accuracy: 0.8571
# Epoch 48/50
# 19/19 [==============================] - 2s 93ms/step - loss: 0.3048 - accuracy: 0.8925 - val_loss: 0.4311 - val_accuracy: 0.8299
# Epoch 49/50
# 19/19 [==============================] - 2s 86ms/step - loss: 0.2056 - accuracy: 0.9283 - val_loss: 0.3102 - val_accuracy: 0.8912
# Epoch 50/50
# 19/19 [==============================] - 2s 90ms/step - loss: 0.1998 - accuracy: 0.9266 - val_loss: 0.3639 - val_accuracy: 0.8707
# Model training completed and saved.
